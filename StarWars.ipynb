# %%
import pandas as pd
import numpy as np

# %%
star_wars = pd.read_csv("StarWars.csv", encoding="ISO-8859-1")

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
# 1  3.292880e+09                                                Yes
# 2  3.292880e+09                                                 No
# 3  3.292765e+09                                                Yes
# 4  3.292763e+09                                                Yes
# 5  3.292731e+09                                                Yes
# 6  3.292719e+09                                                Yes
# 7  3.292685e+09                                                Yes
# 8  3.292664e+09                                                Yes
# 9  3.292654e+09                                                Yes
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
# 1                                                Yes
# ...

# %%
yes_no = {
    "Yes": True,
    "No": False,
    np.NaN: False,
}

# %%
star_wars["Have you seen any of the 6 films in the Star Wars franchise?"] = star_wars["Have you seen any of the 6 films in the Star Wars franchise?"].map(yes_no)

# %%
star_wars["Do you consider yourself to be a fan of the Star Wars film franchise?"] = star_wars["Do you consider yourself to be a fan of the Star Wars film franchise?"].map(yes_no)

# %%
star_wars.head(10)
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                                NaN
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
# 6  3.292719e+09                                               True
# 7  3.292685e+09                                               True
# 8  3.292664e+09                                               True
# 9  3.292654e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                                NaN
# 1                                               True
# ...

# %%
star_wars = star_wars[star_wars["RespondentID"].notnull()]
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 1           Star Wars: Episode I  The Phantom Menace
# 2                                                NaN
# ...

# %%
change_name = {
    "Star Wars: Episode I  The Phantom Menace": True,
    "Star Wars: Episode II  Attack of the Clones": True,
    "Star Wars: Episode III  Revenge of the Sith": True,
    "Star Wars: Episode IV  A New Hope": True,
    "Star Wars: Episode V The Empire Strikes Back": True,
    "Star Wars: Episode VI Return of the Jedi": True,
    np.NaN: False,
}

# %%
for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(change_name)
    
star_wars.head(10)
# Out:
#     RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1   3.292880e+09                                               True
# 2   3.292880e+09                                              False
# 3   3.292765e+09                                               True
# 4   3.292763e+09                                               True
# 5   3.292731e+09                                               True
# 6   3.292719e+09                                               True
# 7   3.292685e+09                                               True
# 8   3.292664e+09                                               True
# 9   3.292654e+09                                               True
# 10  3.292640e+09                                               True
#
#    Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                                True
# 2                                               False
# ...

# %%
star_wars = star_wars.rename(columns={
    "Which of the following Star Wars films have you seen? Please select all that apply.": "seen_1",
    "Unnamed: 4": "seen_2",
    "Unnamed: 5": "seen_3",
    "Unnamed: 6": "seen_4",
    "Unnamed: 7": "seen_5",
    "Unnamed: 8": "seen_6",
})

star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'seen_1', 'seen_2', 'seen_3', 'seen_4', 'seen_5', 'seen_6',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
#        'Are you familiar with the Expanded Universe?',
# ...

# %%
star_wars.head()
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 1  3.292880e+09                                               True
# 2  3.292880e+09                                              False
# 3  3.292765e+09                                               True
# 4  3.292763e+09                                               True
# 5  3.292731e+09                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                               True
# 5                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 1    True    True    True    True    True    True
# 2   False   False   False   False   False   False
# 3    True    True    True   False   False   False
# ...

# %%
star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)

# %%
star_wars.dtypes
# Out:
# RespondentID                                                                                                                                     float64
# Have you seen any of the 6 films in the Star Wars franchise?                                                                                      object
# Do you consider yourself to be a fan of the Star Wars film franchise?                                                                             object
# seen_1                                                                                                                                              bool
# seen_2                                                                                                                                              bool
# seen_3                                                                                                                                              bool
# ...

# %%
star_wars = star_wars.rename(columns={
    "Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.": "ranking_1",
    "Unnamed: 10": "ranking_2",
    "Unnamed: 11": "ranking_3",
    "Unnamed: 12": "ranking_4",
    "Unnamed: 13": "ranking_5",
    "Unnamed: 14": "ranking_6",
})

star_wars.columns
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'seen_1', 'seen_2', 'seen_3', 'seen_4', 'seen_5', 'seen_6', 'ranking_1',
#        'ranking_2', 'ranking_3', 'ranking_4', 'ranking_5', 'ranking_6',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
#        'Are you familiar with the Expanded Universe?',
#        'Do you consider yourself to be a fan of the Expanded Universe?æ',
#        'Do you consider yourself to be a fan of the Star Trek franchise?',
#        'Gender', 'Age', 'Household Income', 'Education',
# ...

# %%
means = star_wars[star_wars.columns[9:15]].mean()

# %%
means
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(range(1,7), means)
plt.xlabel("Movie")
plt.ylabel("Avg ranking")
# Out:
# Text(0, 0.5, 'Avg ranking')

# %%
seen_times = star_wars[star_wars.columns[3:9]].sum()

# %%
seen_times
# Out:
# seen_1    673
# seen_2    571
# seen_3    550
# seen_4    607
# seen_5    758
# seen_6    738
# dtype: int64

# %%
plt.bar(range(1,7), seen_times)
plt.xlabel("Movie")
plt.ylabel("How many times seen")
# Out:
# Text(0, 0.5, 'How many times seen')

# %%
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

# %%
means_males = star_wars[star_wars.columns[9:15]].mean()
means_females = star_wars[star_wars.columns[9:15]].mean()

# %%
plt.bar(range(1,7), means_males)
plt.title("MALE")
plt.xlabel("Movie")
plt.ylabel("Avg ranking")
plt.show()

plt.bar(range(1,7), means_females)
plt.title("FEMALE")
plt.xlabel("Movie")
plt.ylabel("Avg ranking")
plt.show()

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# ...            ...
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                  True
# 5                                                  True
# ...                                                 ...
# 1182                                               True
# 1183                                               True
# 1184                                              False
# 1185                                               True
# 1186                                               True
#
# ...

# %%
star_wars.iloc[:, 15:29]
# Out:
#      Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.  \
# 1                                        Very favorably
# 2                                                   NaN
# 3                                    Somewhat favorably
# 4                                        Very favorably
# 5                                        Very favorably
# ...                                                 ...
# 1182                                     Very favorably
# 1183                                     Very favorably
# 1184                                                NaN
# 1185                                     Very favorably
# 1186                                     Very favorably
#
#                                       Unnamed: 16         Unnamed: 17  \
# 1                                  Very favorably      Very favorably
# 2                                             NaN                 NaN
# ...

# %%
star_wars_firstrow = pd.read_csv("StarWars.csv", encoding="ISO-8859-1")

# %%
star_wars_firstrow = star_wars_firstrow.head(1)
star_wars_firstrow
# Out:
#    RespondentID Have you seen any of the 6 films in the Star Wars franchise?  \
# 0           NaN                                           Response
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                           Response
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
#
#                                     Unnamed: 4  \
# 0  Star Wars: Episode II  Attack of the Clones
#
#                                     Unnamed: 5  \
# 0  Star Wars: Episode III  Revenge of the Sith
#
#                           Unnamed: 6  \
# 0  Star Wars: Episode IV  A New Hope
#
#                                      Unnamed: 7  \
# 0  Star Wars: Episode V The Empire Strikes Back
#
#                                  Unnamed: 8  \
# 0  Star Wars: Episode VI Return of the Jedi
#
# ...

# %%
star_wars_firstrow.iloc[:, 15:29]
# Out:
#   Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.  \
# 0                                           Han Solo
#
#       Unnamed: 16           Unnamed: 17       Unnamed: 18     Unnamed: 19  \
# 0  Luke Skywalker  Princess Leia Organa  Anakin Skywalker  Obi Wan Kenobi
#
#          Unnamed: 20  Unnamed: 21       Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0  Emperor Palpatine  Darth Vader  Lando Calrissian   Boba Fett       C-3P0
#
#   Unnamed: 25    Unnamed: 26    Unnamed: 27 Unnamed: 28
# 0       R2 D2  Jar Jar Binks  Padme Amidala        Yoda

# %%
star_wars.iloc[:, 15:29]
# Out:
#      Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.  \
# 1                                        Very favorably
# 2                                                   NaN
# 3                                    Somewhat favorably
# 4                                        Very favorably
# 5                                        Very favorably
# ...                                                 ...
# 1182                                     Very favorably
# 1183                                     Very favorably
# 1184                                                NaN
# 1185                                     Very favorably
# 1186                                     Very favorably
#
#                                       Unnamed: 16         Unnamed: 17  \
# 1                                  Very favorably      Very favorably
# 2                                             NaN                 NaN
# ...

# %%
star_wars = star_wars.rename(columns={
    "Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.": "Han Solo",
    "Unnamed: 16": "Luke Skywalker",
    "Unnamed: 17": "Princess Leia Organa",
    "Unnamed: 18": "Anakin Skywalker",
    "Unnamed: 19": "Obi Wan Kenobi",
    "Unnamed: 20": "Emperor Palpatine",
    "Unnamed: 21": "Darth Vader",
    "Unnamed: 22": "Lando Calrissian",
    "Unnamed: 23": "Boba Fett",
    "Unnamed: 24": "C-3P0",
    "Unnamed: 25": "R2 D2",
    "Unnamed: 26": "Jar Jar Binks",
    "Unnamed: 27": "Padme Amidala",
    "Unnamed: 28": "Yoda",
})

# %%
star_wars.iloc[:, 15:29]
# Out:
#                 Han Solo                               Luke Skywalker  \
# 1         Very favorably                               Very favorably
# 2                    NaN                                          NaN
# 3     Somewhat favorably                           Somewhat favorably
# 4         Very favorably                               Very favorably
# 5         Very favorably                           Somewhat favorably
# ...                  ...                                          ...
# 1182      Very favorably                           Somewhat favorably
# 1183      Very favorably                           Somewhat favorably
# 1184                 NaN                                          NaN
# 1185      Very favorably  Neither favorably nor unfavorably (neutral)
# 1186      Very favorably                               Very favorably
#
#      Princess Leia Organa      Anakin Skywalker      Obi Wan Kenobi  \
# ...

# %%
star_wars["Han Solo"].unique()
# Out:
# array(['Very favorably', nan, 'Somewhat favorably',
#        'Neither favorably nor unfavorably (neutral)',
#        'Somewhat unfavorably', 'Unfamiliar (N/A)', 'Very unfavorably'],
#       dtype=object)

# %%
star_wars.to_csv('starwars.csv', sep=',', index=False, encoding='utf-8')

# %%
star_wars["Han Solo"].value_counts()
# Out:
# Very favorably                                 610
# Somewhat favorably                             151
# Neither favorably nor unfavorably (neutral)     44
# Unfamiliar (N/A)                                15
# Somewhat unfavorably                             8
# Very unfavorably                                 1
# Name: Han Solo, dtype: int64

# %%
star_wars.columns[15:29]
# Out:
# Index(['Han Solo', 'Luke Skywalker', 'Princess Leia Organa',
#        'Anakin Skywalker', 'Obi Wan Kenobi', 'Emperor Palpatine',
#        'Darth Vader', 'Lando Calrissian', 'Boba Fett', 'C-3P0', 'R2 D2',
#        'Jar Jar Binks', 'Padme Amidala', 'Yoda'],
#       dtype='object')

# %%
for col in star_wars.columns[15:29]:
    print(col)
    print(star_wars[col].value_counts())
# Out:
# Han Solo
# Very favorably                                 610
# Somewhat favorably                             151
# Neither favorably nor unfavorably (neutral)     44
# Unfamiliar (N/A)                                15
# Somewhat unfavorably                             8
# Very unfavorably                                 1
# Name: Han Solo, dtype: int64
# Luke Skywalker
# Very favorably                                 552
# Somewhat favorably                             219
# Neither favorably nor unfavorably (neutral)     38
# Somewhat unfavorably                            13
# Unfamiliar (N/A)                                 6
# Very unfavorably                                 3
# Name: Luke Skywalker, dtype: int64
# Princess Leia Organa
# Very favorably                                 547
# Somewhat favorably                             210
# Neither favorably nor unfavorably (neutral)     48
# Somewhat unfavorably                            12
# ...

# %%
star_wars["Han Solo"].value_counts()[0]
# Out:
# 610

# %%
Very_favorably_counts = []

# %%
for col in star_wars.columns[15:29]:
    Very_favorably_counts.append(col +" "+ str(star_wars[col].value_counts()[0]))

# %%
Very_favorably_counts
# Out:
# ['Han Solo 610',
#  'Luke Skywalker 552',
#  'Princess Leia Organa 547',
#  'Anakin Skywalker 269',
#  'Obi Wan Kenobi 591',
#  'Emperor Palpatine 213',
#  'Darth Vader 310',
#  'Lando Calrissian 236',
#  'Boba Fett 248',
#  'C-3P0 474',
#  'R2 D2 562',
#  'Jar Jar Binks 204',
#  'Padme Amidala 207',
#  'Yoda 605']

# %%
star_wars.iloc[:,:]
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# ...            ...
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                  True
# 5                                                  True
# ...                                                 ...
# 1182                                               True
# 1183                                               True
# 1184                                              False
# 1185                                               True
# 1186                                               True
#
# ...

# %%
star_wars["Do you consider yourself to be a fan of the Star Trek franchise?"] = star_wars["Do you consider yourself to be a fan of the Star Trek franchise?"].map(yes_no)

# %%
star_wars
# Out:
#       RespondentID  \
# 1     3.292880e+09
# 2     3.292880e+09
# 3     3.292765e+09
# 4     3.292763e+09
# 5     3.292731e+09
# ...            ...
# 1182  3.288389e+09
# 1183  3.288379e+09
# 1184  3.288375e+09
# 1185  3.288373e+09
# 1186  3.288373e+09
#
#      Have you seen any of the 6 films in the Star Wars franchise?  \
# 1                                                  True
# 2                                                 False
# 3                                                  True
# 4                                                  True
# 5                                                  True
# ...                                                 ...
# 1182                                               True
# 1183                                               True
# 1184                                              False
# 1185                                               True
# 1186                                               True
#
# ...

# %%
CountStatus = star_wars["Education"].value_counts()

# %%
CountStatus.plot.barh()
# Out:
# <Axes: >

# %%
star_wars["Which character shot first?"].value_counts()
# Out:
# Han                                 325
# I don't understand this question    306
# Greedo                              197
# Name: Which character shot first?, dtype: int64
